# %%
# total = 0
for i in range(10):
    num = int(input("Enter a number: "))
    if num == 0:
        break
    if num < 0:
        continue
    total += num
print("Final sum =", total)
num = int(input("\nEnter a number for multiplication table: "))
for i in range(1, 13):
    product = num * i
    if product % 3 == 0:
        continue
    if product > 50:
        break
    print(num, "x", i, "=", product)
import random
secret = random.randint(1, 20)
attempts = 0
while True:
    guess = int(input("\nGuess the number (1-20): "))
    if guess < 1 or guess > 20:
        continue
    attempts += 1
    if guess == secret:
        print("Correct! Attempts =", attempts)
        break
    else:
        print("Try again!")
n = int(input("\nEnter n: "))
count = 0
for i in range(1, n + 1):
    if i > 50:
        break
    if i % 8 == 0:
        continue
    if i % 4 == 0:
        count += 1
print("Count =", count)
for i in range(1, 6):
    for j in range(1, i + 1):
        if j == 3:
            continue
        if i * j > 6:
            break
        print(j, end=" ")
    print()
# Out:
# Enter a number:  20
# Enter a number:  23
# Enter a number:  13
# Enter a number:  45
# Enter a number:  67
# Enter a number:  42
# Enter a number:  4
# Enter a number:  6
# Enter a number:  7
# Enter a number:  2
# Final sum = 229
# Enter a number for multiplication table:  10
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 4 = 40
# 10 x 5 = 50
# Guess the number (1-20):  12
# Try again!
# Guess the number (1-20):  56
#
# Guess the number (1-20):  11
# Try again!
# Guess the number (1-20):  23
#
# Guess the number (1-20):  45
#
# Guess the number (1-20):  12
# Try again!
# Guess the number (1-20):  67
#
# Guess the number (1-20):  85
#
# Guess the number (1-20):  94
#
# Guess the number (1-20):  55
#
# Guess the number (1-20):  34
#
# Guess the number (1-20):  25
#
# Guess the number (1-20):  10
# Try again!
# Guess the number (1-20):  20
# Try again!
# Guess the number (1-20):  19
# Try again!
# Guess the number (1-20):  111
#
# Guess the number (1-20):  12
# Try again!
# Guess the number (1-20):  3456
#
# Guess the number (1-20):  0
#
# Guess the number (1-20):  34
#
# Guess the number (1-20):  121
#
# Guess the number (1-20):  34
#
# Guess the number (1-20):  98
#
# Guess the number (1-20):  18
# Try again!
# Guess the number (1-20):  5
# Try again!
# Guess the number (1-20):  12
# Try again!
# Guess the number (1-20):  19
# Try again!
# Guess the number (1-20):  18
# Try again!
# Guess the number (1-20):  17
# Try again!
# Guess the number (1-20):  5
# Try again!
# Guess the number (1-20):  8
# Try again!
# Guess the number (1-20):  18
# Try again!
# Guess the number (1-20):  3
# Try again!
# Guess the number (1-20):  8
# Try again!
# Guess the number (1-20):  6
# Correct! Attempts = 19
# Enter n:  4
# Count = 1
# 1
# 1 2
# 1 2
# 1
# 1
